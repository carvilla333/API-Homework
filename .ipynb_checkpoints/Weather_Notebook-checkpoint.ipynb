# %%
# All the dependencies needed
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from api_keys import weather_api_key
from citipy import citipy
import json
import scipy.stats as sts

# %%
# our given file
original_file = "cities.csv"

# %%
# range for latitude and longitude
range_latitude = (-90, 90)
range_longitude = (-180, 180)

# %%
# List that will hold latitudes & longitudes, and a list of cities
latitude_longitude_list = []
cities_list = []

# %%
# this will create a set of random latitudes and longitudes
latitudes = np.random.uniform(range_latitude[0], range_latitude[1], size=1500)
longitudes = np.random.uniform(range_longitude[0], range_longitude[1], size=1500)
latitude_longitude_list = zip(latitudes, longitudes)

# %%
# for loop that will get the nearest city for latitude and longitude
for latitude_and_longitude in latitude_longitude_list:
    city = citipy.nearest_city(latitude_and_longitude[0], latitude_and_longitude[1]).city_name
    
    # every unique city will be added to cities list
    if city not in cities_list:
        cities_list.append(city)
        
len(cities_list)
# Out:
# 619

# %%
# we will query the url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=8ae6e4d8469594724850ae886b985ce2&units=imperial&q='

# %%
# making a request, and getting weather data
weather_request = requests.get(query_url + city)

# we want to make the data look better with dumps in order to see what we want to use for our lists that will store data
request_json = weather_request.json()
print(json.dumps(request_json, indent = 4))
# Out:
# {
#     "coord": {
#         "lon": -97.8558,
#         "lat": 55.7435
#     },
#     "weather": [
#         {
#             "id": 711,
#             "main": "Smoke",
#             "description": "smoke",
#             "icon": "50d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 82.56,
#         "feels_like": 82.2,
#         "temp_min": 82.56,
#         "temp_max": 82.56,
#         "pressure": 1011,
#         "humidity": 42
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13.8,
#         "deg": 240
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1628018875,
#     "sys": {
#         "type": 1,
#         "id": 935,
#         "country": "CA",
#         "sunrise": 1627987265,
#         "sunset": 1628044439
#     },
#     "timezone": -18000,
#     "id": 6165406,
#     "name": "Thompson",
#     "cod": 200
# }

# %%
# these are the list that will store our data
cityName = []
latitude = []
longitude = []
maxTemperature = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []

# %%
# this will be used as a counter
data_record = 1

# %%
# for loop that will go through a list of cities and collect data
for city in cities_list:
    try:
        response = requests.get(query_url + city).json()
        cityName.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        maxTemperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        cityRecord = response["name"]
        print(f"Data Record {data_record} | {cityRecord}") 
        
        
        # Increase Processing Record Counter by 1 For Each Loop
        data_record += 1
        
    except:
        print("No city was found") 
    continue
# Out:
# Data Record 1 | Tiksi
# Data Record 2 | Baykit
# Data Record 3 | Yellowknife
# Data Record 4 | Pevek
# Data Record 5 | Adrar
# Data Record 6 | Jinchang
# Data Record 7 | Lata
# Data Record 8 | Hobart
# Data Record 9 | Djebeniana
# Data Record 10 | Poli
# Data Record 11 | Sawtell
# Data Record 12 | Olinda
# Data Record 13 | Dikson
# Data Record 14 | Chokurdakh
# Data Record 15 | Busselton
# Data Record 16 | Avarua
# Data Record 17 | Kapaa
# Data Record 18 | Bredasdorp
# Data Record 19 | Mount Gambier
# No city was found
# Data Record 20 | Rikitea
# Data Record 21 | Ushuaia
# No city was found
# Data Record 22 | Grand Gaube
# Data Record 23 | Mataura
# Data Record 24 | Pangai
# Data Record 25 | Cuiluan
# Data Record 26 | Severo-Kuril'sk
# Data Record 27 | Hong Kong
# Data Record 28 | Kavieng
# Data Record 29 | Alice Springs
# Data Record 30 | Haines Junction
# Data Record 31 | Kruisfontein
# Data Record 32 | Garden City
# Data Record 33 | Krasnoarmeysk
# Data Record 34 | Bluff
# Data Record 35 | Clyde River
# Data Record 36 | Esperance
# Data Record 37 | Qaanaaq
# Data Record 38 | Malakal
# Data Record 39 | Ambilobe
# Data Record 40 | Vaini
# Data Record 41 | Port Alfred
# Data Record 42 | Tombouctou
# Data Record 43 | Willowmore
# Data Record 44 | Bethel
# Data Record 45 | Omboué
# Data Record 46 | Alyangula
# Data Record 47 | Verāval
# Data Record 48 | Albany
# Data Record 49 | Isabela
# Data Record 50 | Seoul
# Data Record 51 | Yangi Marg`ilon
# Data Record 52 | Kabalo
# Data Record 53 | Vestmannaeyjar
# No city was found
# Data Record 54 | Kungurtug
# No city was found
# Data Record 55 | Hilo
# Data Record 56 | Ostrovnoy
# Data Record 57 | Punta Arenas
# Data Record 58 | Yamada
# Data Record 59 | Mandalgovi
# Data Record 60 | Tasiilaq
# Data Record 61 | Tuktoyaktuk
# Data Record 62 | North Bend
# Data Record 63 | Poplar Bluff
# Data Record 64 | Barrow
# Data Record 65 | San Jerónimo
# Data Record 66 | Yima
# Data Record 67 | Provideniya
# Data Record 68 | Cabo San Lucas
# Data Record 69 | Praia
# Data Record 70 | Nikolskoye
# Data Record 71 | Departamento de Maldonado
# Data Record 72 | Anloga
# Data Record 73 | Talnakh
# Data Record 74 | Río Gallegos
# Data Record 75 | Disna
# Data Record 76 | New Norfolk
# Data Record 77 | Neepawa
# Data Record 78 | Lamar
# No city was found
# Data Record 79 | Ribeira Grande
# Data Record 80 | Sakaiminato
# Data Record 81 | Plaeng Yao
# Data Record 82 | Atuona
# Data Record 83 | Alta Floresta
# Data Record 84 | Cidreira
# Data Record 85 | Nome
# Data Record 86 | Kampot
# Data Record 87 | Puerto Ayora
# Data Record 88 | Port Elizabeth
# No city was found
# Data Record 89 | Khatanga
# Data Record 90 | Masty
# Data Record 91 | Hermanus
# Data Record 92 | George Town
# Data Record 93 | Saskylakh
# Data Record 94 | Ridgecrest
# Data Record 95 | Saint-Philippe
# Data Record 96 | Touros
# Data Record 97 | Kavaratti
# Data Record 98 | San Matías
# Data Record 99 | East London
# Data Record 100 | Naze
# Data Record 101 | Kiama
# No city was found
# Data Record 102 | Baghdad
# Data Record 103 | Walvis Bay
# Data Record 104 | Denpasar
# Data Record 105 | Porto-Novo
# Data Record 106 | Bhānvad
# Data Record 107 | Butaritari
# Data Record 108 | Jamestown
# Data Record 109 | Carnarvon
# Data Record 110 | Northam
# Data Record 111 | Port Blair
# Data Record 112 | Saint Paul Harbor
# Data Record 113 | Coyhaique
# Data Record 114 | Geraldton
# Data Record 115 | Sambava
# Data Record 116 | São Filipe
# Data Record 117 | Den Helder
# No city was found
# Data Record 118 | Lebu
# Data Record 119 | Padang
# Data Record 120 | Ivybridge
# Data Record 121 | Leh
# Data Record 122 | Thompson
# Data Record 123 | Cape Town
# Data Record 124 | Shingū
# Data Record 125 | Henties Bay
# Data Record 126 | Tautira
# Data Record 127 | Roald
# Data Record 128 | Rocha
# Data Record 129 | Lorengau
# Data Record 130 | Rimbey
# Data Record 131 | Ixtapa
# Data Record 132 | Bowen
# Data Record 133 | Upernavik
# Data Record 134 | Churapcha
# Data Record 135 | Shirokiy
# Data Record 136 | Changli
# Data Record 137 | Illela
# Data Record 138 | Washougal
# Data Record 139 | Letychiv
# No city was found
# Data Record 140 | Mikuni
# Data Record 141 | Khanbari
# Data Record 142 | Nanortalik
# Data Record 143 | Dunda
# No city was found
# Data Record 144 | Cooma
# Data Record 145 | Tabou
# Data Record 146 | Oskarshamn
# Data Record 147 | Chenzhou
# Data Record 148 | Saint-Augustin
# Data Record 149 | Barra de Tecoanapa
# Data Record 150 | Bathsheba
# No city was found
# Data Record 151 | Businga
# Data Record 152 | San Vicente
# Data Record 153 | Cherskiy
# No city was found
# Data Record 154 | Picota
# Data Record 155 | Kjøllefjord
# Data Record 156 | Russell
# Data Record 157 | Pangody
# Data Record 158 | Hithadhoo
# Data Record 159 | Camacupa
# Data Record 160 | Bilma
# Data Record 161 | Marzuq
# Data Record 162 | Zhalantun
# No city was found
# Data Record 163 | Yulara
# Data Record 164 | Prince Rupert
# Data Record 165 | Adra
# Data Record 166 | Mossamedes
# Data Record 167 | Markova
# Data Record 168 | Yerbogachën
# Data Record 169 | Guerrero Negro
# Data Record 170 | Nuevo Progreso
# Data Record 171 | Arlit
# Data Record 172 | Avera
# Data Record 173 | Progreso
# Data Record 174 | Bambous Virieux
# No city was found
# No city was found
# Data Record 175 | Los Llanos de Aridane
# Data Record 176 | Ringe
# Data Record 177 | Muyezerskiy
# Data Record 178 | Wellington
# Data Record 179 | Buluang
# Data Record 180 | Dingzhou
# Data Record 181 | Saint George
# Data Record 182 | Ende
# Data Record 183 | Yumen
# No city was found
# Data Record 184 | Mar del Plata
# Data Record 185 | Peniche
# Data Record 186 | Andenes
# Data Record 187 | Edd
# Data Record 188 | Iporá
# Data Record 189 | Oneonta
# Data Record 190 | San Cristobal
# Data Record 191 | Pisco
# Data Record 192 | Port Moresby
# Data Record 193 | Fortuna
# No city was found
# Data Record 194 | Tsurib
# Data Record 195 | Moses Lake
# Data Record 196 | Ust-Nera
# Data Record 197 | San Francisco
# Data Record 198 | Archidona
# Data Record 199 | Omiš
# Data Record 200 | High Level
# Data Record 201 | Nouadhibou
# Data Record 202 | Ayagoz
# Data Record 203 | Dudinka
# Data Record 204 | Muzhi
# Data Record 205 | Morón
# No city was found
# Data Record 206 | Hay River
# No city was found
# Data Record 207 | Enshi
# Data Record 208 | Saint-Pierre
# Data Record 209 | Bushehr
# Data Record 210 | Coquimbo
# Data Record 211 | Te Anau
# Data Record 212 | Faanui
# Data Record 213 | La Macarena
# Data Record 214 | Iqaluit
# Data Record 215 | Eyl
# Data Record 216 | Borsad
# Data Record 217 | Kudymkar
# Data Record 218 | Tual
# Data Record 219 | Camacha
# Data Record 220 | Moïssala
# Data Record 221 | Kano
# Data Record 222 | Chui
# Data Record 223 | Payo
# Data Record 224 | Marsh Harbour
# Data Record 225 | Vytegra
# Data Record 226 | Hasaki
# Data Record 227 | Goderich
# Data Record 228 | Batagay-Alyta
# Data Record 229 | Samarai
# Data Record 230 | Dossor
# No city was found
# Data Record 231 | Newtownards
# Data Record 232 | Athabasca
# Data Record 233 | Vanavara
# Data Record 234 | Paita
# Data Record 235 | Las Vegas
# Data Record 236 | Harlingen
# Data Record 237 | Meulaboh
# Data Record 238 | Auki
# Data Record 239 | Saint-Gabriel
# Data Record 240 | Gao
# Data Record 241 | Dillon
# Data Record 242 | Koulamoutou
# No city was found
# Data Record 243 | Teluk Nibung
# Data Record 244 | Tavricheskoye
# Data Record 245 | Plymouth
# Data Record 246 | Airai
# Data Record 247 | Bontang
# Data Record 248 | Port Macquarie
# Data Record 249 | Vidim
# Data Record 250 | Aktau
# No city was found
# Data Record 251 | Lüderitz
# Data Record 252 | Grindavik
# No city was found
# Data Record 253 | Kumla
# Data Record 254 | Warrnambool
# Data Record 255 | Khrebtovaya
# Data Record 256 | Richards Bay
# Data Record 257 | Tataouine
# Data Record 258 | Asău
# No city was found
# Data Record 259 | Maningrida
# Data Record 260 | Ancud
# No city was found
# Data Record 261 | Portland
# Data Record 262 | Longyearbyen
# Data Record 263 | Hamilton
# Data Record 264 | Havelock
# Data Record 265 | Souillac
# Data Record 266 | Dali
# Data Record 267 | Tubualá
# Data Record 268 | Kahului
# Data Record 269 | Tymovskoye
# No city was found
# Data Record 270 | Finschhafen
# Data Record 271 | Norman Wells
# Data Record 272 | Vardø
# No city was found
# Data Record 273 | Cayenne
# Data Record 274 | Orange
# Data Record 275 | Macusani
# Data Record 276 | Sorong
# Data Record 277 | Cedar Lake
# Data Record 278 | Jalu
# Data Record 279 | Palmer
# Data Record 280 | Gijang
# Data Record 281 | Arraial do Cabo
# Data Record 282 | Tiébissou
# Data Record 283 | Bandarbeyla
# Data Record 284 | Codrington
# No city was found
# No city was found
# Data Record 285 | Emmett
# Data Record 286 | North Battleford
# Data Record 287 | Oleksandrivka
# Data Record 288 | Jiwani
# Data Record 289 | Ilulissat
# Data Record 290 | Yārāda
# Data Record 291 | Canoinhas
# Data Record 292 | Vila
# Data Record 293 | Pavlovsk
# Data Record 294 | Chittarkonda
# Data Record 295 | Muli
# Data Record 296 | Kieta
# Data Record 297 | Gizo Government Station
# Data Record 298 | San Patricio
# Data Record 299 | Jacareacanga
# Data Record 300 | Belen
# No city was found
# Data Record 301 | Alofi
# Data Record 302 | Quatre Cocos
# Data Record 303 | Barcelos
# No city was found
# Data Record 304 | Fort Nelson
# Data Record 305 | Camaná
# Data Record 306 | Kuznechnoye
# Data Record 307 | Mahébourg
# Data Record 308 | Edéa
# Data Record 309 | Shāhpur
# Data Record 310 | Katsuura
# Data Record 311 | Aleksandrov Gay
# Data Record 312 | La Palma
# Data Record 313 | Tura
# Data Record 314 | Ghanzi
# Data Record 315 | Gilleleje
# Data Record 316 | Newcastle
# Data Record 317 | Paamiut
# Data Record 318 | Castro
# Data Record 319 | Namatanai
# Data Record 320 | Morant Bay
# Data Record 321 | Tamandaré
# Data Record 322 | Amalāpuram
# Data Record 323 | Quelimane
# Data Record 324 | Bambanglipuro
# No city was found
# Data Record 325 | Damaturu
# No city was found
# Data Record 326 | Torrington
# Data Record 327 | Beloha
# Data Record 328 | Poum
# Data Record 329 | Coahuayana Viejo
# Data Record 330 | Leningradskiy
# Data Record 331 | São João da Barra
# Data Record 332 | Mayo
# Data Record 333 | Kudahuvadhoo
# Data Record 334 | San Roque
# Data Record 335 | Zeya
# Data Record 336 | Khovu-Aksy
# No city was found
# No city was found
# Data Record 337 | Sarkand
# Data Record 338 | Darhan
# Data Record 339 | Kanniyākumāri
# Data Record 340 | Qaqortoq
# Data Record 341 | Saldanha
# Data Record 342 | Katangli
# Data Record 343 | Nyírlugos
# Data Record 344 | Gaoual
# Data Record 345 | Swan River
# No city was found
# Data Record 346 | Belaya Gora
# Data Record 347 | Plaster Rock
# Data Record 348 | Makhu
# Data Record 349 | Ingham
# Data Record 350 | North Platte
# Data Record 351 | Ocampo
# Data Record 352 | Karasjok
# Data Record 353 | Puro
# Data Record 354 | Mungaoli
# No city was found
# Data Record 355 | Ponta do Sol
# Data Record 356 | Yaan
# Data Record 357 | San Quintín
# Data Record 358 | Mount Isa
# No city was found
# Data Record 359 | Venice
# Data Record 360 | Zonguldak
# No city was found
# Data Record 361 | Lincoln
# Data Record 362 | Laguna
# Data Record 363 | Half Moon Bay
# Data Record 364 | Iglesias
# Data Record 365 | Muros
# Data Record 366 | San Felipe
# Data Record 367 | Sungai Penuh
# Data Record 368 | Fairbanks
# No city was found
# Data Record 369 | Bulgan
# Data Record 370 | Myanaung
# Data Record 371 | Mehamn
# Data Record 372 | Lavrentiya
# Data Record 373 | Gurkovo
# Data Record 374 | Lagoa
# Data Record 375 | Etchoropo
# Data Record 376 | Esso
# Data Record 377 | Vostok
# Data Record 378 | Nova Olímpia
# Data Record 379 | Qeshm
# Data Record 380 | Pochutla
# Data Record 381 | Vaitape
# Data Record 382 | Port-Gentil
# Data Record 383 | Manadhoo
# Data Record 384 | Novikovo
# Data Record 385 | Dinguiraye
# Data Record 386 | Santa Luzia
# Data Record 387 | Bengkulu
# Data Record 388 | Maţāy
# Data Record 389 | Mīrābād
# Data Record 390 | Narsaq
# Data Record 391 | Kiunga
# Data Record 392 | Zyryanka
# Data Record 393 | Okhotsk
# Data Record 394 | Cap Malheureux
# Data Record 395 | Aitape
# No city was found
# Data Record 396 | Mariinsk
# Data Record 397 | Walla Walla
# Data Record 398 | Karratha
# Data Record 399 | Lompoc
# Data Record 400 | Butajīra
# Data Record 401 | Tuatapere
# Data Record 402 | Pasaje
# Data Record 403 | Nefteyugansk
# Data Record 404 | Faya
# Data Record 405 | Pimenta Bueno
# Data Record 406 | Bedelē
# Data Record 407 | Mumford
# Data Record 408 | Basti
# Data Record 409 | Rincon
# Data Record 410 | Halifax
# Data Record 411 | Burnie
# No city was found
# Data Record 412 | Zinapécuaro
# Data Record 413 | Dubovskoye
# No city was found
# Data Record 414 | Araouane
# No city was found
# Data Record 415 | Salekhard
# Data Record 416 | Chumikan
# Data Record 417 | Montevideo
# Data Record 418 | Tofield
# Data Record 419 | Kibiti
# Data Record 420 | Olafsvik
# Data Record 421 | Kassala
# Data Record 422 | Cornwall
# Data Record 423 | Vestmanna
# Data Record 424 | Topolobampo
# Data Record 425 | Wanaka
# Data Record 426 | Petropavlovsk-Kamchatskiy
# Data Record 427 | Santiago
# Data Record 428 | Benguela
# Data Record 429 | Harper
# Data Record 430 | Kharp
# Data Record 431 | Maniitsoq
# No city was found
# Data Record 432 | Caravelas
# No city was found
# Data Record 433 | Whitehorse
# Data Record 434 | Igualada
# Data Record 435 | Marovoay
# Data Record 436 | Tazovsky
# Data Record 437 | Arrondissement de Cambrai
# Data Record 438 | Sola
# Data Record 439 | Pocatello
# No city was found
# Data Record 440 | Kostroma
# Data Record 441 | Ambulu
# Data Record 442 | Xingyi
# Data Record 443 | Moree
# Data Record 444 | Selenduma
# Data Record 445 | Pho Thong
# Data Record 446 | Klaksvík
# Data Record 447 | Ronneby
# Data Record 448 | Itapirapuã
# Data Record 449 | Luorong
# Data Record 450 | Waverly
# Data Record 451 | Rome
# Data Record 452 | Marawi
# Data Record 453 | Saint-François
# Data Record 454 | Imbituba
# Data Record 455 | Mezen'
# Data Record 456 | Gudāri
# Data Record 457 | Riohacha
# Data Record 458 | Taoudenni
# Data Record 459 | Agirish
# Data Record 460 | Beyneu
# Data Record 461 | Puerto del Rosario
# Data Record 462 | Yurimaguas
# Data Record 463 | Slavutych
# Data Record 464 | Sal Rei
# Data Record 465 | Derveni
# Data Record 466 | Torbay
# Data Record 467 | Salalah
# Data Record 468 | Kaitangata
# No city was found
# No city was found
# Data Record 469 | Verkhoyansk
# Data Record 470 | Manama
# Data Record 471 | Riachão das Neves
# Data Record 472 | Heraclea
# Data Record 473 | Rawlins
# Data Record 474 | Esperantina
# Data Record 475 | Constantine
# Data Record 476 | Nebolchi
# Data Record 477 | Semey
# Data Record 478 | Ukiah
# Data Record 479 | Balaipungut
# No city was found
# Data Record 480 | Ketchikan
# Data Record 481 | Santa Fe
# Data Record 482 | São Félix do Xingu
# Data Record 483 | Ahipara
# Data Record 484 | Ola
# Data Record 485 | Zyryanskoye
# No city was found
# Data Record 486 | Raudeberg
# Data Record 487 | Alekseyevsk
# Data Record 488 | Watsa
# Data Record 489 | Ves'yegonsk
# Data Record 490 | Pacific Grove
# Data Record 491 | Rio Grande
# Data Record 492 | Gelibolu
# Data Record 493 | Kosh-Agach
# Data Record 494 | Champerico
# Data Record 495 | Ekibastuz
# Data Record 496 | Muaná
# Data Record 497 | Huadian
# Data Record 498 | St. George's
# Data Record 499 | Vung Tau
# Data Record 500 | Lexington Park
# Data Record 501 | Augsburg
# Data Record 502 | Santa Vitória
# Data Record 503 | Acapulco de Juárez
# Data Record 504 | Killybegs
# Data Record 505 | Fukuechō
# Data Record 506 | Bonavista
# Data Record 507 | Tacuarembó
# Data Record 508 | Sabang
# Data Record 509 | Garoowe
# Data Record 510 | Kurayoshi
# Data Record 511 | Hermosillo
# Data Record 512 | Gogrial
# Data Record 513 | Štíty
# Data Record 514 | Messina
# Data Record 515 | Kununurra
# Data Record 516 | Vao
# Data Record 517 | Hearst
# Data Record 518 | Husavik
# Data Record 519 | Yangambi
# Data Record 520 | Correntina
# Data Record 521 | Fos-sur-Mer
# No city was found
# Data Record 522 | Gaoua
# No city was found
# Data Record 523 | Kaeo
# Data Record 524 | Ca Mau
# Data Record 525 | Manitouwadge
# Data Record 526 | Kiryat Gat
# Data Record 527 | Bitung
# Data Record 528 | Gweta
# Data Record 529 | Mocuba
# Data Record 530 | Menzel Salem
# Data Record 531 | Quinto di Treviso
# Data Record 532 | Porto Santo
# Data Record 533 | Hokitika
# Data Record 534 | Aketi
# Data Record 535 | Fallon
# Data Record 536 | Abay
# Data Record 537 | Gouré
# Data Record 538 | Cauquenes
# Data Record 539 | Cortez
# Data Record 540 | Sistranda
# No city was found
# Data Record 541 | Ponta Delgada
# Data Record 542 | Colares
# Data Record 543 | Muzaffarabad
# Data Record 544 | Kodoli
# Data Record 545 | Ust-Tsilma
# Data Record 546 | Makhachkala
# Data Record 547 | Villa Hayes
# Data Record 548 | Riyadh
# Data Record 549 | Margate
# No city was found
# Data Record 550 | Villa María
# Data Record 551 | Nagar
# Data Record 552 | Luk Pu
# Data Record 553 | Boffa
# Data Record 554 | Domoni
# Data Record 555 | Bariloche
# Data Record 556 | Aklavik
# Data Record 557 | Nago
# Data Record 558 | Korla
# Data Record 559 | Anadyr
# Data Record 560 | Gopālpur
# Data Record 561 | Shar
# Data Record 562 | San Luis
# Data Record 563 | Teya
# Data Record 564 | Bagotville

# %%
# we are making a dataframe from the data collected
weather_data_dictionary = {
    "City": cityName,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": maxTemperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": windSpeed,
    "Country": country,
    "Date": date,
}

weather_dataframe = pd.DataFrame(weather_data_dictionary)
weather_dataframe.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# the current dataframe
weather_dataframe
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tiksi  71.6872  128.8694     43.07        81          83
# 1         Baykit  61.6700   96.3700     62.28        89          76
# 2    Yellowknife  62.4560 -114.3525     62.56        67          90
# 3          Pevek  69.7008  170.3133     37.24        86          67
# 4          Adrar  20.5022  -10.0711     91.90        32          12
# ..           ...      ...       ...       ...       ...         ...
# 559     Gopālpur  19.2667   84.9167     82.09        77         100
# 560         Shar  49.5886   81.0453     67.75        60          19
# 561     San Luis -33.2950  -66.3356     69.71        21          35
# 562         Teya  60.3778   92.6267     60.87        72          86
# 563   Bagotville -28.9833  153.4167     53.49        61           0
#
#      Wind Speed Country        Date
# 0          9.48      RU  1628019158
# 1          3.96      RU  1628019158
# 2          5.99      CA  1628019069
# 3          3.74      RU  1628019159
# 4          9.93      MR  1628019159
# ..          ...     ...         ...
# 559        5.79      IN  1628019327
# 560        5.28      KZ  1628019327
# 561        1.72      AR  1628019328
# 562        0.27      RU  1628019328
# 563        8.63      AU  1628019328
#
# [564 rows x 9 columns]

# %%
# getting rid of data that has humidity more than 100
humidity_dataframe= weather_dataframe.loc[weather_dataframe["Humidity"] >=100]
humidity_dataframe
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 45                   Alyangula -13.8483  136.4192     67.87       100
# 286              Oleksandrivka  46.8383   32.7612     75.15       100
# 422                  Vestmanna  62.1564   -7.1664     50.92       100
# 425  Petropavlovsk-Kamchatskiy  53.0452  158.6483     41.59       100
# 446                    Ronneby  56.2100   15.2760     55.90       100
#
#      Cloudiness  Wind Speed Country        Date
# 45           84        1.14      AU  1628019171
# 286         100        8.03      UA  1628019238
# 422          75        5.75      FO  1628019278
# 425           0        4.47      RU  1628019279
# 446          49        0.00      SE  1628019285

# %%
# dataframe with humidity that is not 100%
humidity_dataframe_cleaned= weather_dataframe.loc[(weather_dataframe["Humidity"] < 100)]
humidity_dataframe_cleaned
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tiksi  71.6872  128.8694     43.07        81          83
# 1         Baykit  61.6700   96.3700     62.28        89          76
# 2    Yellowknife  62.4560 -114.3525     62.56        67          90
# 3          Pevek  69.7008  170.3133     37.24        86          67
# 4          Adrar  20.5022  -10.0711     91.90        32          12
# ..           ...      ...       ...       ...       ...         ...
# 559     Gopālpur  19.2667   84.9167     82.09        77         100
# 560         Shar  49.5886   81.0453     67.75        60          19
# 561     San Luis -33.2950  -66.3356     69.71        21          35
# 562         Teya  60.3778   92.6267     60.87        72          86
# 563   Bagotville -28.9833  153.4167     53.49        61           0
#
#      Wind Speed Country        Date
# 0          9.48      RU  1628019158
# 1          3.96      RU  1628019158
# 2          5.99      CA  1628019069
# 3          3.74      RU  1628019159
# 4          9.93      MR  1628019159
# ..          ...     ...         ...
# 559        5.79      IN  1628019327
# 560        5.28      KZ  1628019327
# 561        1.72      AR  1628019328
# 562        0.27      RU  1628019328
# 563        8.63      AU  1628019328
#
# [559 rows x 9 columns]

# %%
# exporting data frame to 
humidity_dataframe_cleaned.to_csv("clean_cities_data.csv", encoding ="utf-8", index=False)

# %%
# Plot for max temperature vs latitude
plt.scatter(humidity_dataframe_cleaned["Max Temp"], humidity_dataframe_cleaned["Lat"])
plt.ylabel("Latitude")
plt.xlabel("Temperature")
plt.title("Max Temperature vs Latitude")
# Out:
# Text(0.5, 1.0, 'Max Temperature vs Latitude')

# %%
# plot for Humidity vs Latitude
plt.scatter(humidity_dataframe_cleaned["Humidity"], humidity_dataframe_cleaned["Lat"])
plt.ylabel("Latitude")
plt.xlabel("Humidity")
plt.title("Humidity vs Latitude")
# Out:
# Text(0.5, 1.0, 'Humidity vs Latitude')

# %%
# plot for Cloudiness vs Latitude
plt.scatter(humidity_dataframe_cleaned["Cloudiness"], humidity_dataframe_cleaned["Lat"])
plt.ylabel("Latitude")
plt.xlabel("Cloudiness")
plt.title("Cloudiness vs Latitude")
# Out:
# Text(0.5, 1.0, 'Cloudiness vs Latitude')

# %%
# plot for Wind Speed vs Latitude
plt.scatter(humidity_dataframe_cleaned["Wind Speed"], humidity_dataframe_cleaned["Lat"])
plt.ylabel("Latitude")
plt.xlabel("Wind Speed")
plt.title("Wind Speed vs Latitude")
# Out:
# Text(0.5, 1.0, 'Wind Speed vs Latitude')

# %%
# new dataframe from north hemisphere
northern_df = humidity_dataframe_cleaned.loc[humidity_dataframe_cleaned["Lat"] >= 0.0]
northern_df.reset_index(inplace=True)

# %%
# linear regression for north temperature vs latitude
north_hem_temp = northern_df["Max Temp"]
north_hem_lat = northern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(north_hem_temp, north_hem_lat)
fit = slope * north_hem_temp + int
plt.scatter(northern_df["Max Temp"], northern_df["Lat"])
plt.plot(north_hem_temp, fit, "r-")
plt.xlabel("Temperature")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# linear regression for north humidity vs latitude
north_hem_hum = northern_df["Humidity"]
north_hem_lat = northern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(north_hem_hum, north_hem_lat)
fit = slope * north_hem_hum + int
plt.scatter(northern_df["Humidity"], northern_df["Lat"])
plt.plot(north_hem_hum, fit, "r-")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# linear regression for north cloudiness vs latitude
north_hem_clo = northern_df["Cloudiness"]
north_hem_lat = northern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(north_hem_clo, north_hem_lat)
fit = slope * north_hem_clo + int
plt.scatter(northern_df["Cloudiness"], northern_df["Lat"])
plt.plot(north_hem_clo, fit, "r-")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# linear regression for north wind speed vs latitude
north_hem_wind = northern_df["Wind Speed"]
north_hem_lat = northern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(north_hem_wind, north_hem_lat)
fit = slope * north_hem_wind + int
plt.scatter(northern_df["Wind Speed"], northern_df["Lat"])
plt.plot(north_hem_wind, fit, "r-")
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# new dataframe from south
southern_df = humidity_dataframe_cleaned.loc[humidity_dataframe_cleaned["Lat"] < 0.0]
southern_df.reset_index(inplace=True)

# %%
# linear regression for south temperature vs latitude
south_hem_temp = southern_df["Max Temp"]
south_hem_lat = southern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(south_hem_temp, south_hem_lat)
fit = slope * south_hem_temp + int
plt.scatter(southern_df["Max Temp"], southern_df["Lat"])
plt.plot(south_hem_temp, fit, "r-")
plt.xlabel("Temperature")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# linear regression for south humidity vs latitude
south_hem_hum = southern_df["Humidity"]
south_hem_lat = southern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(south_hem_hum, south_hem_lat)
fit = slope * south_hem_hum + int
plt.scatter(southern_df["Humidity"], southern_df["Lat"])
plt.plot(south_hem_hum, fit, "r-")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# linear regression for south cloudiness vs latitude
south_hem_cloud =southern_df["Cloudiness"]
south_hem_lat = southern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(south_hem_cloud, south_hem_lat)
fit = slope * south_hem_cloud + int
plt.scatter(southern_df["Cloudiness"], southern_df["Lat"])
plt.plot(south_hem_cloud, fit, "r-")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
# linear regression for south wind speed vs latitude
south_hem_wind =southern_df["Wind Speed"]
south_hem_lat = southern_df["Lat"]
slope, int, r, p, std_err = sts.linregress(south_hem_wind, south_hem_lat)
fit = slope * south_hem_wind + int
plt.scatter(southern_df["Wind Speed"], southern_df["Lat"])
plt.plot(south_hem_wind, fit, "r-")
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')
